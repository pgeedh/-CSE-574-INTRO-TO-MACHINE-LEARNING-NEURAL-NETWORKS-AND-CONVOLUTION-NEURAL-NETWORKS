# %% [markdown]
# <div align="center"> <h3><font color='blue'>CSE 574: Introduction to Machine Learning, Summer 2022 </font>
# <h1> Assignment 3
#
# Building Neural Networks and CNN
#
# <h2><font color='red'>Checkpoint: </font>  July 1, Fri, 11:59pm </div>
#
# <h3><font color='blue'>Description: </div>
#
# Welcome to our third assignment. This assignment focuses on building fully connected
# neural networks (NN) and convolutional neural networks (CNN). It consists of two parts
# where you practice dealing with large datasets and implement, train, adjust neural
# networks.
# The first part consists of performing data analysis (which you know is the first step for
# every ML project) and building a basic NN. In the second part, we will implement a basic
# CNN.
# Apart from this do not miss out some extra bonus points, by completing the task
# described at the end of this description.
# Note for using Libraries: For this assignment any pre-trained or pre-build neural
# networks or CNN architectures cannot be used (e.g. torchvision.models,
# keras.applications). This time you are welcome to use scikit-learn for data
# preprocessing. You are expected to use TensorFlow, Keras or PyTorch libraries to build
# a NN (e.g. works using sklearn.neural_network.MLPClassifier won't be evaluated)
#
#
#
# ###Part I: : Building a Basic NN [50 points]
# In this part we will work on Income dataset. You must achieve a minimum accuracy of
# 82%. Take guidance from the steps mentioned below.
#
#
# ###STEPS
# 1.Load, preprocess, analyze the dataset and make it ready for training. You can
# refer to Assignment 2: Part 1 - Data Analysis steps. Applying the right
# preprocessing techniques can help you increase the accuracy. Refer here for
# more details on preprocessing methods.
#
# 2.Build and train a basic NN (with max 3 hidden layers).
# You can use TensorFlow, PyTorch or Keras as a deep learning framework.
# Decide your NN architecture:
# - How many input neurons are there?
# - What activation function will you choose?
# - What is the number of hidden layers? (1, 2 or 3?)
# - What is the size of each hidden layer?
# - What activation function is used for the hidden and output layer?
# 3.Test your NN on the test dataset.
#
#
#
# ###In your report for Part I
# 1.Provide brief details about the nature of your dataset. What is it about? What
# type of data are we encountering? How many entries and variables does the
# dataset comprise? Provide the main statistics about the entries of the dataset.
#
# 2.Provide at least 3 visualization graphs with short description for each graph.
#
# 3.For the preprocessing part, discuss if you use any preprocessing tools, that helps
# to increase the accuracy of your model.
#
# 4.Provide the architecture structure of your NN.
#
# 5.Provide graphs that compares test and training accuracy on the same plot and
# test and training loss on the same plot. Thus, in total two graphs with a clear
# labeling.
#
#
#
# ### Academic Integrity
#
# This assignment must be completed individually.
# The standing policy of the Department is that all students involved in any academic integrity violation (e.g. plagiarism in any way, shape, or form) will receive an F grade for the course. The catalog describes plagiarism as “Copying or receiving material from any source and submitting that material as one’s own, without acknowledging and citing the particular debts to the source, or in any other manner representing the work of another as one’s own.”. Refer to the [Office of Academic Integrity](https://www.buffalo.edu/academic-integrity.html) for more details.
#
#
# ### Late Days Policy
# You can use up to 3 late days throughout the course toward any assignments. You do not have to inform the instructor, as the late submission will be tracked in UBlearns.
#
# ### FAQ
# >What does 'raise Exception("Not implemented yet")' mean?
#
# Here we define a custom exception to highlight that the task is not implemented yet. Once you implement your code, ensure to remove this part.
#
# >Can I add code beyond # BEGIN_YOUR_CODE parts.
#
# Yes, you can add helper functions. Add them in the separate cell with the comments, why you need it.

# %% [markdown]
# **PART II: Logistic Regression-:**

# %% [markdown]
# ###IMPORTING LIABRARIES

# %%
# Importing the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ###LOADING DATASET

# %%
# !pwd
# !ls
# Out:
# /content
# sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd ..
# %cd /content/drive/MyDrive
from google.colab import files
uploaded = files.upload()
print("dataset loaded")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive
# /content/drive/MyDrive
#      <input type="file" id="files-e1d76ef4-cc4b-4a98-80e7-b3b97a3583b9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e1d76ef4-cc4b-4a98-80e7-b3b97a3583b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving income_dataset.csv to income_dataset (9).csv
# dataset loaded

# %% [markdown]
# ###Income Dataset (income_dataset.csv)

# %%
#Reading the dataset
df_income=pd.read_csv('income_dataset.csv')

# %%
#Printing the first 10 rows of the income dataset using .head
print("First 10 rows of the income datset:")
df_income.head(10) #prints first 10 rows of the datset
# Out:
# First 10 rows of the income datset:
#    age    workclass  fnlwgt     education  education.num marital.status  \
# 0   90            ?   77053       HS-grad              9        Widowed
# 1   82      Private  132870       HS-grad              9        Widowed
# 2   66            ?  186061  Some-college             10        Widowed
# 3   54      Private  140359       7th-8th              4       Divorced
# 4   41      Private  264663  Some-college             10      Separated
# 5   34      Private  216864       HS-grad              9       Divorced
# 6   38      Private  150601          10th              6      Separated
# 7   74    State-gov   88638     Doctorate             16  Never-married
# 8   68  Federal-gov  422013       HS-grad              9       Divorced
# 9   41      Private   70037  Some-college             10  Never-married
#
#           occupation    relationship   race     sex  capital.gain  \
# 0                  ?   Not-in-family  White  Female             0
# 1    Exec-managerial   Not-in-family  White  Female             0
# 2                  ?       Unmarried  Black  Female             0
# 3  Machine-op-inspct       Unmarried  White  Female             0
# 4     Prof-specialty       Own-child  White  Female             0
# 5      Other-service       Unmarried  White  Female             0
# 6       Adm-clerical       Unmarried  White    Male             0
# 7     Prof-specialty  Other-relative  White  Female             0
# 8     Prof-specialty   Not-in-family  White  Female             0
# 9       Craft-repair       Unmarried  White    Male             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K
# 5          3770              45  United-States  <=50K
# 6          3770              40  United-States  <=50K
# 7          3683              20  United-States   >50K
# 8          3683              40  United-States  <=50K
# 9          3004              60              ?   >50K

# %%
#Printing the names of the columns of the dataset
columns=df_income.columns #saves the column names of the dataset in variable  columns
print("Printing coloumn names  of the dataset: \n")
print(columns ) #prints the names of columns
# Out:
# Printing coloumn names  of the dataset:
#
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
#Printing the shape of the dataset
shape = df_income.shape #saves the shape of the dataset in variable shape
print("Shape of the dataset:")
print(shape) #prints the shape
# Out:
# Shape of the dataset:
# (32561, 15)

# %%
#Printing the statistics of the income dataset
print("Printing statstics of the income dataset:")
df_income.describe(include='all') #describes the mean, std, etc.. for the dataset
# Out:
# Printing statstics of the income dataset:
#                  age workclass        fnlwgt education  education.num  \
# count   32561.000000     32561  3.256100e+04     32561   32561.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581647       NaN  1.897784e+05       NaN      10.080679
# std        13.640433       NaN  1.055500e+05       NaN       2.572720
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#             marital.status      occupation relationship   race    sex  \
# count                32561           32561        32561  32561  32561
# unique                   7              15            6      5      2
# top     Married-civ-spouse  Prof-specialty      Husband  White   Male
# freq                 14976            4140        13193  27816  21790
# mean                   NaN             NaN          NaN    NaN    NaN
# std                    NaN             NaN          NaN    NaN    NaN
# min                    NaN             NaN          NaN    NaN    NaN
# 25%                    NaN             NaN          NaN    NaN    NaN
# 50%                    NaN             NaN          NaN    NaN    NaN
# 75%                    NaN             NaN          NaN    NaN    NaN
# max                    NaN             NaN          NaN    NaN    NaN
#
#         capital.gain  capital.loss  hours.per.week native.country income
# count   32561.000000  32561.000000    32561.000000          32561  32561
# unique           NaN           NaN             NaN             42      2
# top              NaN           NaN             NaN  United-States  <=50K
# freq             NaN           NaN             NaN          29170  24720
# mean     1077.648844     87.303830       40.437456            NaN    NaN
# std      7385.292085    402.960219       12.347429            NaN    NaN
# min         0.000000      0.000000        1.000000            NaN    NaN
# 25%         0.000000      0.000000       40.000000            NaN    NaN
# 50%         0.000000      0.000000       40.000000            NaN    NaN
# 75%         0.000000      0.000000       45.000000            NaN    NaN
# max     99999.000000   4356.000000       99.000000            NaN    NaN

# %%
#Value count of each type of education
df_income['education'].value_counts()
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
#Printing the datatypes of various columns
types=df_income.dtypes #saves the datatypes of the dataset in variable types
print("Printing datatypes of each coloums in the dataset:")
print(types)  #prints the different datatypes n of columns
# Out:
# Printing datatypes of each coloums in the dataset:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %% [markdown]
# ###CHECKING NULL VALUES

# %%
#checking for null values in the dataset
null=df_income.isnull().sum(axis=0)
print(null)#prints the number of null values in the dataset
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
#printing the general information of the income dataset
df_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
#converting object type to caterory
df_income['workclass'] = df_income['workclass'].astype('category') # converts the object datatype to catergory
df_income['education'] = df_income['education'].astype('category') # converts the object datatype to catergory
df_income['marital.status'] = df_income['marital.status'].astype('category') # converts the object datatype to catergory
df_income['occupation'] = df_income['occupation'].astype('category') # converts the object datatype to catergory
df_income['relationship'] = df_income['relationship'].astype('category') # converts the object datatype to catergory
df_income['race'] = df_income['race'].astype('category') # converts the object datatype to catergory
df_income['sex'] = df_income['sex'].astype('category') # converts the object datatype to catergory
df_income['native.country'] = df_income['native.country'].astype('category') # converts the object datatype to catergory
df_income['income'] = df_income['income'].astype('category') # converts the object datatype to catergory

# %%
#printing the general information of the income dataset after conversion
df_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  category
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  category
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  category
#  6   occupation      32561 non-null  category
#  7   relationship    32561 non-null  category
#  8   race            32561 non-null  category
#  9   sex             32561 non-null  category
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  category
#  14  income          32561 non-null  category
# dtypes: category(9), int64(6)
# memory usage: 1.8 MB

# %%
# Replacing '?' values in the columns with NaN
df_income.replace("?", np.nan, inplace = True) #replacing the ? with nan values
df_income.isnull().any(axis=1).sum()
# Out:
# 2399

# %%
#Handling missing values and drpping them
df_income.dropna(inplace=True) #dropping the missing values

# %%
df_income.head(10)
# Out:
#     age         workclass  fnlwgt     education  education.num marital.status  \
# 1    82           Private  132870       HS-grad              9        Widowed
# 3    54           Private  140359       7th-8th              4       Divorced
# 4    41           Private  264663  Some-college             10      Separated
# 5    34           Private  216864       HS-grad              9       Divorced
# 6    38           Private  150601          10th              6      Separated
# 7    74         State-gov   88638     Doctorate             16  Never-married
# 8    68       Federal-gov  422013       HS-grad              9       Divorced
# 10   45           Private  172274     Doctorate             16       Divorced
# 11   38  Self-emp-not-inc  164526   Prof-school             15  Never-married
# 12   52           Private  129177     Bachelors             13        Widowed
#
#            occupation    relationship   race     sex  capital.gain  \
# 1     Exec-managerial   Not-in-family  White  Female             0
# 3   Machine-op-inspct       Unmarried  White  Female             0
# 4      Prof-specialty       Own-child  White  Female             0
# 5       Other-service       Unmarried  White  Female             0
# 6        Adm-clerical       Unmarried  White    Male             0
# 7      Prof-specialty  Other-relative  White  Female             0
# 8      Prof-specialty   Not-in-family  White  Female             0
# 10     Prof-specialty       Unmarried  Black  Female             0
# 11     Prof-specialty   Not-in-family  White    Male             0
# 12      Other-service   Not-in-family  White  Female             0
#
#     capital.loss  hours.per.week native.country income
# 1           4356              18  United-States  <=50K
# 3           3900              40  United-States  <=50K
# 4           3900              40  United-States  <=50K
# 5           3770              45  United-States  <=50K
# 6           3770              40  United-States  <=50K
# 7           3683              20  United-States   >50K
# 8           3683              40  United-States  <=50K
# 10          3004              35  United-States   >50K
# 11          2824              45  United-States   >50K
# 12          2824              20  United-States   >50K

# %% [markdown]
# ###DATA VISUALIZATION

# %%
#Plotting a violin plot for workclass and age with hue income
fig=plt.figure(figsize=(12,8)) #size of the figure
sn.violinplot(x='workclass', y='age', data=df_income,hue='income',split=True) 
plt.show()

# %%
#Bar plot for count in different attributes

fig, ax = plt.subplots(3, 2, figsize=(16, 14), constrained_layout=True) #size and layout of the plot

sn.countplot(x='marital.status', data=df_income, ax=ax[1,0])
ax[1,0].set_xticklabels(ax[1,0].get_xticklabels(), rotation=90, fontsize=10) 

sn.countplot(x='education', data=df_income, ax=ax[0,1])
ax[0,1].set_xticklabels(ax[0,1].get_xticklabels(), rotation=90, fontsize=10)

sn.countplot(x='workclass', data=df_income, ax=ax[0,0])
ax[0,0].set_xticklabels(ax[0,0].get_xticklabels(), rotation=90, fontsize=10)

sn.countplot(x='occupation', data=df_income, ax=ax[1,1])
ax[1,1].set_xticklabels(ax[1,1].get_xticklabels(), rotation=90, fontsize=10)

sn.countplot(x='relationship', data=df_income, ax=ax[2,0])
ax[2,0].set_xticklabels(ax[2,0].get_xticklabels(), rotation=90, fontsize=10)

sn.countplot(x='native.country', data=df_income, ax=ax[2,1])
ax[2,1].set_xticklabels(ax[2,1].get_xticklabels(), rotation=90, fontsize=10)

sn.countplot(x='marital.status', data=df_income, ax=ax[1,0])
ax[1,0].set_xticklabels(ax[1,0].get_xticklabels(), rotation=90, fontsize=10)
plt.show()

# %%
# Impact of education on income
plt.figure(figsize=(12,8)) #size of the fig
ax = sn.countplot(x='occupation', hue='income', data=df_income)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, fontsize=10) #labels the graph and roates the names for better visibility
plt.show()

# %%
# Multivariate  plot to check Impact of occupation and relationships on income using countplots
plt.figure(figsize=(12,8)) #size of the plot
work = sn.catplot(x='occupation', hue='relationship', col='sex', data=df_income, kind='count')
work.set_xticklabels(rotation=90, fontsize=10) #labels the graph and roates the names for better representation
plt.show()

# %%
#bi-variate graph for workclass in the dataset
fig=plt.figure(figsize=(12,8)) #size of the figure
sn.pairplot(df_income, hue="workclass", corner=True)
plt.show()

# %%
#correlation matrix
matrix = df_income.corr() #finds correlation 
print(matrix)
plt.figure(figsize=(12,10)) #fig size
sn.heatmap(df_income.corr()) #plots the heat map
plt.title('Correlation Heat Map') #titles the plot
plt.show()
# Out:
#                      age    fnlwgt  education.num  capital.gain  capital.loss  \
# age             1.000000 -0.076511       0.043526      0.080154      0.060165
# fnlwgt         -0.076511  1.000000      -0.044992      0.000422     -0.009750
# education.num   0.043526 -0.044992       1.000000      0.124416      0.079646
# capital.gain    0.080154  0.000422       0.124416      1.000000     -0.032229
# capital.loss    0.060165 -0.009750       0.079646     -0.032229      1.000000
# hours.per.week  0.101599 -0.022886       0.152522      0.080432      0.052417
#
#                 hours.per.week
# age                   0.101599
# fnlwgt               -0.022886
# education.num         0.152522
# capital.gain          0.080432
# capital.loss          0.052417
# hours.per.week        1.000000

# %% [markdown]
# ###ONE HOT ENCODING

# %%
# checking if we need both education and education_num columns
for edu in df_income['education'].unique():
    print(edu,":", df_income[df_income['education'] == edu]["education.num"].nunique())
# Out:
# HS-grad : 1
# 7th-8th : 1
# Some-college : 1
# 10th : 1
# Doctorate : 1
# Prof-school : 1
# Bachelors : 1
# Masters : 1
# 11th : 1
# Assoc-voc : 1
# 1st-4th : 1
# 5th-6th : 1
# Assoc-acdm : 1
# 12th : 1
# 9th : 1
# Preschool : 1

# %%
# we observe that 'education.num' is unique for each value of 'education' Thus, we remove 'education' column for better compilation
df_income = df_income.drop(columns = ['education'])

# %%
# One-hot encoding the categorical variables to use in NN model
df_income = pd.get_dummies(df_income, drop_first=True)
df_income.head()
# Out:
#    age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week  \
# 1   82  132870              9             0          4356              18
# 3   54  140359              4             0          3900              40
# 4   41  264663             10             0          3900              40
# 5   34  216864              9             0          3770              45
# 6   38  150601              6             0          3770              40
#
#    workclass_Local-gov  workclass_Never-worked  workclass_Private  \
# 1                    0                       0                  1
# 3                    0                       0                  1
# 4                    0                       0                  1
# 5                    0                       0                  1
# 6                    0                       0                  1
#
#    workclass_Self-emp-inc  ...  native.country_Puerto-Rico  \
# 1                       0  ...                           0
# 3                       0  ...                           0
# 4                       0  ...                           0
# 5                       0  ...                           0
# 6                       0  ...                           0
#
#    native.country_Scotland  native.country_South  native.country_Taiwan  \
# 1                        0                     0                      0
# 3                        0                     0                      0
# 4                        0                     0                      0
# 5                        0                     0                      0
# 6                        0                     0                      0
#
#    native.country_Thailand  native.country_Trinadad&Tobago  \
# 1                        0                               0
# 3                        0                               0
# 4                        0                               0
# 5                        0                               0
# 6                        0                               0
#
#    native.country_United-States  native.country_Vietnam  \
# 1                             1                       0
# 3                             1                       0
# 4                             1                       0
# 5                             1                       0
# 6                             1                       0
#
#    native.country_Yugoslavia  income_>50K
# 1                          0            0
# 3                          0            0
# 4                          0            0
# 5                          0            0
# 6                          0            0
#
# [5 rows x 83 columns]

# %%
#Checking the info for the dataset after processing
df_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30162 entries, 1 to 32560
# Data columns (total 83 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   age                                        30162 non-null  int64
#  1   fnlwgt                                     30162 non-null  int64
#  2   education.num                              30162 non-null  int64
#  3   capital.gain                               30162 non-null  int64
#  4   capital.loss                               30162 non-null  int64
#  5   hours.per.week                             30162 non-null  int64
#  6   workclass_Local-gov                        30162 non-null  uint8
#  7   workclass_Never-worked                     30162 non-null  uint8
#  8   workclass_Private                          30162 non-null  uint8
#  9   workclass_Self-emp-inc                     30162 non-null  uint8
#  10  workclass_Self-emp-not-inc                 30162 non-null  uint8
#  11  workclass_State-gov                        30162 non-null  uint8
#  12  workclass_Without-pay                      30162 non-null  uint8
#  13  marital.status_Married-AF-spouse           30162 non-null  uint8
#  14  marital.status_Married-civ-spouse          30162 non-null  uint8
#  15  marital.status_Married-spouse-absent       30162 non-null  uint8
#  16  marital.status_Never-married               30162 non-null  uint8
#  17  marital.status_Separated                   30162 non-null  uint8
#  18  marital.status_Widowed                     30162 non-null  uint8
#  19  occupation_Armed-Forces                    30162 non-null  uint8
#  20  occupation_Craft-repair                    30162 non-null  uint8
#  21  occupation_Exec-managerial                 30162 non-null  uint8
#  22  occupation_Farming-fishing                 30162 non-null  uint8
#  23  occupation_Handlers-cleaners               30162 non-null  uint8
#  24  occupation_Machine-op-inspct               30162 non-null  uint8
#  25  occupation_Other-service                   30162 non-null  uint8
#  26  occupation_Priv-house-serv                 30162 non-null  uint8
#  27  occupation_Prof-specialty                  30162 non-null  uint8
#  28  occupation_Protective-serv                 30162 non-null  uint8
#  29  occupation_Sales                           30162 non-null  uint8
#  30  occupation_Tech-support                    30162 non-null  uint8
#  31  occupation_Transport-moving                30162 non-null  uint8
#  32  relationship_Not-in-family                 30162 non-null  uint8
#  33  relationship_Other-relative                30162 non-null  uint8
#  34  relationship_Own-child                     30162 non-null  uint8
#  35  relationship_Unmarried                     30162 non-null  uint8
#  36  relationship_Wife                          30162 non-null  uint8
#  37  race_Asian-Pac-Islander                    30162 non-null  uint8
#  38  race_Black                                 30162 non-null  uint8
#  39  race_Other                                 30162 non-null  uint8
#  40  race_White                                 30162 non-null  uint8
#  41  sex_Male                                   30162 non-null  uint8
#  42  native.country_Canada                      30162 non-null  uint8
#  43  native.country_China                       30162 non-null  uint8
#  44  native.country_Columbia                    30162 non-null  uint8
#  45  native.country_Cuba                        30162 non-null  uint8
#  46  native.country_Dominican-Republic          30162 non-null  uint8
#  47  native.country_Ecuador                     30162 non-null  uint8
#  48  native.country_El-Salvador                 30162 non-null  uint8
#  49  native.country_England                     30162 non-null  uint8
#  50  native.country_France                      30162 non-null  uint8
#  51  native.country_Germany                     30162 non-null  uint8
#  52  native.country_Greece                      30162 non-null  uint8
#  53  native.country_Guatemala                   30162 non-null  uint8
#  54  native.country_Haiti                       30162 non-null  uint8
#  55  native.country_Holand-Netherlands          30162 non-null  uint8
#  56  native.country_Honduras                    30162 non-null  uint8
#  57  native.country_Hong                        30162 non-null  uint8
#  58  native.country_Hungary                     30162 non-null  uint8
#  59  native.country_India                       30162 non-null  uint8
#  60  native.country_Iran                        30162 non-null  uint8
#  61  native.country_Ireland                     30162 non-null  uint8
#  62  native.country_Italy                       30162 non-null  uint8
#  63  native.country_Jamaica                     30162 non-null  uint8
#  64  native.country_Japan                       30162 non-null  uint8
#  65  native.country_Laos                        30162 non-null  uint8
#  66  native.country_Mexico                      30162 non-null  uint8
#  67  native.country_Nicaragua                   30162 non-null  uint8
#  68  native.country_Outlying-US(Guam-USVI-etc)  30162 non-null  uint8
#  69  native.country_Peru                        30162 non-null  uint8
#  70  native.country_Philippines                 30162 non-null  uint8
#  71  native.country_Poland                      30162 non-null  uint8
#  72  native.country_Portugal                    30162 non-null  uint8
#  73  native.country_Puerto-Rico                 30162 non-null  uint8
#  74  native.country_Scotland                    30162 non-null  uint8
#  75  native.country_South                       30162 non-null  uint8
#  76  native.country_Taiwan                      30162 non-null  uint8
#  77  native.country_Thailand                    30162 non-null  uint8
#  78  native.country_Trinadad&Tobago             30162 non-null  uint8
#  79  native.country_United-States               30162 non-null  uint8
#  80  native.country_Vietnam                     30162 non-null  uint8
#  81  native.country_Yugoslavia                  30162 non-null  uint8
#  82  income_>50K                                30162 non-null  uint8
# dtypes: int64(6), uint8(77)
# memory usage: 4.8 MB

# %%
# min-max scaling of the continuous features
continuous_columns = ["age", "fnlwgt", "capital.loss", "capital.gain", "education.num", "hours.per.week"]

for col in continuous_columns:
    df_income[col] = (df_income[col] - df_income[col].min()) / (df_income[col].max() - df_income[col].min())

# %%
# initializing the target variable 
X = df_income.iloc[:, :-1]
y = df_income["income_>50K"]

# %%
from sklearn.model_selection import train_test_split
# Split Train and Test Datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20) #splittig the dataset in test and train with 80% and random state of 50

# %%
#print(X_train)

# %%
#printitng the shape of the dataset
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
print("shape of the test train split")
# Out:
# (24129, 82)
# (24129,)
# (6033, 82)
# (6033,)
# shape of the test train split

# %% [markdown]
# ###PART 1: NEURAL NETWORK MODEL

# %% [markdown]
# ###initializing the neural network

# %%
#Input features to the first hidden layer of 256 neurons, followed by two additional hidden layers of 512 and 1024 neurons each.
#There’s a 1-neuron output layer at the end. Hidden layers use ReLU as the activation function, and the output layer uses Sigmoid as activation fucntion
import tensorflow as tf #importing tensor flow
tf.random.set_seed(42)

nn_model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation='relu',input_shape = (82,)), tf.keras.layers.Dense(512, activation='relu'), tf.keras.layers.Dense(1024, activation='relu'),tf.keras.layers.Dense(1, activation='sigmoid')
])

nn_model.compile(
    loss=tf.keras.losses.mse, #loss fucntion
    optimizer=tf.keras.optimizers.Adamax(learning_rate=0.005), #adamax optimiser with 0.005 learing rate
    metrics=[tf.keras.metrics.BinaryAccuracy(name='accuracy'),tf.keras.metrics.Precision(name='precision'),tf.keras.metrics.Recall(name='recall')
    ]
)

# %%
#neural network model summary
nn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 256)               21248
#
#  dense_9 (Dense)             (None, 512)               131584
#
#  dense_10 (Dense)            (None, 1024)              525312
#
#  dense_11 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 679,169
# Trainable params: 679,169
# Non-trainable params: 0
# _________________________________________________________________

# %%
#history= nn_model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs = 100, batch_size=256)

# %%
#training the neural network on train data with 50 epochs and batch size =256
nn_history = nn_model.fit(X_train, y_train,
          batch_size=256, epochs=50,
          validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 95/95 [==============================] - 6s 51ms/step - loss: 0.1352 - accuracy: 0.8114 - precision: 0.6709 - recall: 0.4716 - val_loss: 0.1194 - val_accuracy: 0.8323 - val_precision: 0.7174 - val_recall: 0.5501
# Epoch 2/50
# 95/95 [==============================] - 3s 36ms/step - loss: 0.1096 - accuracy: 0.8385 - precision: 0.7081 - recall: 0.5945 - val_loss: 0.1173 - val_accuracy: 0.8286 - val_precision: 0.7881 - val_recall: 0.4361
# Epoch 3/50
# 95/95 [==============================] - 3s 33ms/step - loss: 0.1055 - accuracy: 0.8463 - precision: 0.7287 - recall: 0.6070 - val_loss: 0.1104 - val_accuracy: 0.8437 - val_precision: 0.7213 - val_recall: 0.6173
# Epoch 4/50
# 95/95 [==============================] - 3s 33ms/step - loss: 0.1027 - accuracy: 0.8515 - precision: 0.7363 - recall: 0.6259 - val_loss: 0.1088 - val_accuracy: 0.8472 - val_precision: 0.7463 - val_recall: 0.5949
# Epoch 5/50
# 95/95 [==============================] - 3s 33ms/step - loss: 0.1005 - accuracy: 0.8550 - precision: 0.7458 - recall: 0.6309 - val_loss: 0.1098 - val_accuracy: 0.8432 - val_precision: 0.7046 - val_recall: 0.6489
# Epoch 6/50
# 95/95 [==============================] - 3s 32ms/step - loss: 0.0994 - accuracy: 0.8562 - precision: 0.7440 - recall: 0.6417 - val_loss: 0.1101 - val_accuracy: 0.8447 - val_precision: 0.6954 - val_recall: 0.6812
# Epoch 7/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0979 - accuracy: 0.8576 - precision: 0.7483 - recall: 0.6427 - val_loss: 0.1084 - val_accuracy: 0.8449 - val_precision: 0.7137 - val_recall: 0.6403
# Epoch 8/50
# 95/95 [==============================] - 3s 33ms/step - loss: 0.0965 - accuracy: 0.8617 - precision: 0.7556 - recall: 0.6546 - val_loss: 0.1082 - val_accuracy: 0.8498 - val_precision: 0.7742 - val_recall: 0.5692
# Epoch 9/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0968 - accuracy: 0.8605 - precision: 0.7536 - recall: 0.6511 - val_loss: 0.1092 - val_accuracy: 0.8470 - val_precision: 0.7621 - val_recall: 0.5698
# Epoch 10/50
# 95/95 [==============================] - 3s 36ms/step - loss: 0.0945 - accuracy: 0.8644 - precision: 0.7678 - recall: 0.6504 - val_loss: 0.1083 - val_accuracy: 0.8478 - val_precision: 0.7613 - val_recall: 0.5758
# Epoch 11/50
# 95/95 [==============================] - 3s 35ms/step - loss: 0.0940 - accuracy: 0.8646 - precision: 0.7607 - recall: 0.6629 - val_loss: 0.1091 - val_accuracy: 0.8468 - val_precision: 0.7725 - val_recall: 0.5547
# Epoch 12/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0936 - accuracy: 0.8641 - precision: 0.7599 - recall: 0.6619 - val_loss: 0.1095 - val_accuracy: 0.8460 - val_precision: 0.7627 - val_recall: 0.5632
# Epoch 13/50
# 95/95 [==============================] - 3s 33ms/step - loss: 0.0923 - accuracy: 0.8668 - precision: 0.7628 - recall: 0.6726 - val_loss: 0.1112 - val_accuracy: 0.8445 - val_precision: 0.6908 - val_recall: 0.6917
# Epoch 14/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0920 - accuracy: 0.8673 - precision: 0.7698 - recall: 0.6643 - val_loss: 0.1085 - val_accuracy: 0.8493 - val_precision: 0.7478 - val_recall: 0.6054
# Epoch 15/50
# 95/95 [==============================] - 3s 35ms/step - loss: 0.0909 - accuracy: 0.8690 - precision: 0.7688 - recall: 0.6751 - val_loss: 0.1107 - val_accuracy: 0.8452 - val_precision: 0.7068 - val_recall: 0.6574
# Epoch 16/50
# 95/95 [==============================] - 3s 35ms/step - loss: 0.0901 - accuracy: 0.8708 - precision: 0.7710 - recall: 0.6820 - val_loss: 0.1098 - val_accuracy: 0.8475 - val_precision: 0.7235 - val_recall: 0.6377
# Epoch 17/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0902 - accuracy: 0.8698 - precision: 0.7671 - recall: 0.6828 - val_loss: 0.1108 - val_accuracy: 0.8485 - val_precision: 0.7408 - val_recall: 0.6120
# Epoch 18/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0895 - accuracy: 0.8709 - precision: 0.7738 - recall: 0.6783 - val_loss: 0.1108 - val_accuracy: 0.8465 - val_precision: 0.7170 - val_recall: 0.6443
# Epoch 19/50
# 95/95 [==============================] - 3s 36ms/step - loss: 0.0893 - accuracy: 0.8714 - precision: 0.7775 - recall: 0.6750 - val_loss: 0.1108 - val_accuracy: 0.8465 - val_precision: 0.6987 - val_recall: 0.6858
# Epoch 20/50
# 95/95 [==============================] - 3s 35ms/step - loss: 0.0882 - accuracy: 0.8727 - precision: 0.7708 - recall: 0.6935 - val_loss: 0.1115 - val_accuracy: 0.8473 - val_precision: 0.7246 - val_recall: 0.6344
# Epoch 21/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0885 - accuracy: 0.8719 - precision: 0.7753 - recall: 0.6815 - val_loss: 0.1101 - val_accuracy: 0.8518 - val_precision: 0.7332 - val_recall: 0.6462
# Epoch 22/50
# 95/95 [==============================] - 3s 35ms/step - loss: 0.0870 - accuracy: 0.8736 - precision: 0.7739 - recall: 0.6932 - val_loss: 0.1104 - val_accuracy: 0.8472 - val_precision: 0.7332 - val_recall: 0.6173
# Epoch 23/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0873 - accuracy: 0.8748 - precision: 0.7790 - recall: 0.6922 - val_loss: 0.1104 - val_accuracy: 0.8516 - val_precision: 0.7439 - val_recall: 0.6258
# Epoch 24/50
# 95/95 [==============================] - 3s 35ms/step - loss: 0.0866 - accuracy: 0.8748 - precision: 0.7815 - recall: 0.6883 - val_loss: 0.1114 - val_accuracy: 0.8439 - val_precision: 0.7118 - val_recall: 0.6377
# Epoch 25/50
# 95/95 [==============================] - 3s 35ms/step - loss: 0.0868 - accuracy: 0.8739 - precision: 0.7763 - recall: 0.6912 - val_loss: 0.1112 - val_accuracy: 0.8472 - val_precision: 0.7231 - val_recall: 0.6364
# Epoch 26/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0855 - accuracy: 0.8765 - precision: 0.7754 - recall: 0.7073 - val_loss: 0.1117 - val_accuracy: 0.8493 - val_precision: 0.7442 - val_recall: 0.6113
# Epoch 27/50
# 95/95 [==============================] - 3s 35ms/step - loss: 0.0853 - accuracy: 0.8766 - precision: 0.7868 - recall: 0.6900 - val_loss: 0.1162 - val_accuracy: 0.8362 - val_precision: 0.6610 - val_recall: 0.7167
# Epoch 28/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0850 - accuracy: 0.8763 - precision: 0.7761 - recall: 0.7053 - val_loss: 0.1105 - val_accuracy: 0.8498 - val_precision: 0.7567 - val_recall: 0.5942
# Epoch 29/50
# 95/95 [==============================] - 3s 35ms/step - loss: 0.0845 - accuracy: 0.8779 - precision: 0.7769 - recall: 0.7129 - val_loss: 0.1116 - val_accuracy: 0.8450 - val_precision: 0.7265 - val_recall: 0.6159
# Epoch 30/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0840 - accuracy: 0.8789 - precision: 0.7822 - recall: 0.7100 - val_loss: 0.1129 - val_accuracy: 0.8440 - val_precision: 0.7270 - val_recall: 0.6087
# Epoch 31/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0844 - accuracy: 0.8767 - precision: 0.7819 - recall: 0.6980 - val_loss: 0.1132 - val_accuracy: 0.8424 - val_precision: 0.6938 - val_recall: 0.6686
# Epoch 32/50
# 95/95 [==============================] - 3s 35ms/step - loss: 0.0834 - accuracy: 0.8781 - precision: 0.7833 - recall: 0.7037 - val_loss: 0.1135 - val_accuracy: 0.8467 - val_precision: 0.7075 - val_recall: 0.6660
# Epoch 33/50
# 95/95 [==============================] - 3s 35ms/step - loss: 0.0830 - accuracy: 0.8796 - precision: 0.7869 - recall: 0.7060 - val_loss: 0.1143 - val_accuracy: 0.8435 - val_precision: 0.6982 - val_recall: 0.6660
# Epoch 34/50
# 95/95 [==============================] - 3s 35ms/step - loss: 0.0820 - accuracy: 0.8804 - precision: 0.7873 - recall: 0.7100 - val_loss: 0.1146 - val_accuracy: 0.8424 - val_precision: 0.7018 - val_recall: 0.6495
# Epoch 35/50
# 95/95 [==============================] - 3s 33ms/step - loss: 0.0820 - accuracy: 0.8798 - precision: 0.7824 - recall: 0.7145 - val_loss: 0.1162 - val_accuracy: 0.8392 - val_precision: 0.6879 - val_recall: 0.6607
# Epoch 36/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0813 - accuracy: 0.8811 - precision: 0.7897 - recall: 0.7102 - val_loss: 0.1140 - val_accuracy: 0.8435 - val_precision: 0.7274 - val_recall: 0.6047
# Epoch 37/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0815 - accuracy: 0.8817 - precision: 0.7893 - recall: 0.7140 - val_loss: 0.1182 - val_accuracy: 0.8366 - val_precision: 0.6766 - val_recall: 0.6713
# Epoch 38/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0809 - accuracy: 0.8827 - precision: 0.7927 - recall: 0.7144 - val_loss: 0.1145 - val_accuracy: 0.8450 - val_precision: 0.7203 - val_recall: 0.6278
# Epoch 39/50
# 95/95 [==============================] - 3s 35ms/step - loss: 0.0800 - accuracy: 0.8840 - precision: 0.7918 - recall: 0.7225 - val_loss: 0.1143 - val_accuracy: 0.8430 - val_precision: 0.7201 - val_recall: 0.6153
# Epoch 40/50
# 95/95 [==============================] - 3s 33ms/step - loss: 0.0802 - accuracy: 0.8838 - precision: 0.7951 - recall: 0.7167 - val_loss: 0.1158 - val_accuracy: 0.8409 - val_precision: 0.6888 - val_recall: 0.6706
# Epoch 41/50
# 95/95 [==============================] - 3s 33ms/step - loss: 0.0791 - accuracy: 0.8858 - precision: 0.7959 - recall: 0.7260 - val_loss: 0.1147 - val_accuracy: 0.8452 - val_precision: 0.7626 - val_recall: 0.5586
# Epoch 42/50
# 95/95 [==============================] - 3s 33ms/step - loss: 0.0794 - accuracy: 0.8867 - precision: 0.8036 - recall: 0.7192 - val_loss: 0.1152 - val_accuracy: 0.8419 - val_precision: 0.7173 - val_recall: 0.6133
# Epoch 43/50
# 95/95 [==============================] - 3s 33ms/step - loss: 0.0785 - accuracy: 0.8867 - precision: 0.7977 - recall: 0.7282 - val_loss: 0.1193 - val_accuracy: 0.8384 - val_precision: 0.6846 - val_recall: 0.6634
# Epoch 44/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0778 - accuracy: 0.8861 - precision: 0.7931 - recall: 0.7321 - val_loss: 0.1170 - val_accuracy: 0.8463 - val_precision: 0.7257 - val_recall: 0.6258
# Epoch 45/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0771 - accuracy: 0.8898 - precision: 0.8052 - recall: 0.7336 - val_loss: 0.1175 - val_accuracy: 0.8419 - val_precision: 0.7120 - val_recall: 0.6238
# Epoch 46/50
# 95/95 [==============================] - 4s 37ms/step - loss: 0.0768 - accuracy: 0.8899 - precision: 0.8041 - recall: 0.7357 - val_loss: 0.1161 - val_accuracy: 0.8419 - val_precision: 0.7323 - val_recall: 0.5856
# Epoch 47/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0770 - accuracy: 0.8886 - precision: 0.8028 - recall: 0.7307 - val_loss: 0.1171 - val_accuracy: 0.8392 - val_precision: 0.7003 - val_recall: 0.6311
# Epoch 48/50
# 95/95 [==============================] - 3s 35ms/step - loss: 0.0761 - accuracy: 0.8911 - precision: 0.8076 - recall: 0.7371 - val_loss: 0.1172 - val_accuracy: 0.8437 - val_precision: 0.7200 - val_recall: 0.6199
# Epoch 49/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0761 - accuracy: 0.8905 - precision: 0.8048 - recall: 0.7381 - val_loss: 0.1166 - val_accuracy: 0.8415 - val_precision: 0.7385 - val_recall: 0.5731
# Epoch 50/50
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0760 - accuracy: 0.8895 - precision: 0.8023 - recall: 0.7362 - val_loss: 0.1193 - val_accuracy: 0.8392 - val_precision: 0.6932 - val_recall: 0.6476

# %%
#testing evaluation
nn_model.evaluate(X_test, y_test)[1]
# Out:
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1193 - accuracy: 0.8392 - precision: 0.6932 - recall: 0.6476
# 0.8392176628112793

# %%
#plotting loss to epoch
fig=plt.figure(figsize=(12,8)) #size of the figure
plt.plot(nn_history.history['loss'])
plt.plot(nn_history.history['val_loss']) 
plt.title('Total Loss Plot') 
plt.xlabel('Epoch') 
plt.ylabel('Loss') 
plt.legend(['Train', 'Test'], loc='upper left') 
plt.show()

# %%
#plotting model accuracy
fig=plt.figure(figsize=(12,8)) #size of the figure
plt.plot(nn_history.history['accuracy'])
plt.plot(nn_history.history['val_accuracy'])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend(['Train','Validation'],loc='lower left')
plt.show()

# %% [markdown]
# # References
#
#
# 1. Numpy - https://numpy.org/doc/stable/user/absolute_beginners.html
#        to get the basic idea of numpy and it's usage
# 2. Pandas - https://pandas.pydata.org/docs/reference/frame.html
#        to get basic functions of pandas
# 3. Stack Overflow - https://stackoverflow.com
#        to fix errors while solving the above assignment
# 4. Real Python for pandas - https://realpython.com/pandas-python-explore-dataset/
#        Exploring different functions of reading and working with a dataset.
# 5. Matplotlib for plotting heat maps: https://machinelearningknowledge.ai/matplotlib-heatmap-complete-tutorial-for-beginners/
#        Referred for link to plot the heatmaps and syntax for plotting
# 6. Matplotlib - https://www.geeksforgeeks.org/python-introduction-matplotlib/ and https://matplotlib.org/stable/tutorials/index
#        Learn the basics of matplotlib for plotting graphs.
# 7. Seaborn Tutorial - https://www.geeksforgeeks.org/python-seaborn-tutorial/
#        Learn the basics of plotting graphs using seaborn
# 8. Plotly Tutorial - https://plotly.com/python/
#        Learnt the basics of plotting graphs using plotly
#
# 9.https://numpy.org/doc/stable/reference/generated/numpy.linalg.inv.html
#
# 10.https://numpy.org/doc/stable/reference/generated/numpy.identity.html
#
#
# 11) https://numpy.org/doc/stable/reference/generated/numpy.identity.html
#
# 12) https://numpy.org/doc/stable/reference/generated/numpy.linalg.inv.html
#
# 13) https://stackoverflow.com/questions/38125319/python-divide-by-zero-encountered-in-log
# -logistic-regression
#
# 14) https://numpy.org/doc/stable/reference/generated/numpy.dot.html
#
# 16) https://datatofish.com/line-chart-python-matplotlib/
#
# 17) https://pandas.pydata.org/docs/reference/frame.html
#
# 18) https://matplotlib.org/stable/tutorials/introductory/usage.html#sphx-glr-tutorials-introduct
# ory-usage-py
#
# 19)https://keras.io/api/
#
# 20) https://keras.io/api/models/sequential/
#
# 21) https://numpy.org/
#
# 22) https://keras.io/api/models/model_training_apis/#fit-method
#
# 23) https://keras.io/api/callbacks/model_checkpoint/
#
# 24) https://keras.io/api/optimizers/
#
# 25) https://keras.io/api/layers/activations/
#
#
# 26) https://keras.io/api/
#
# 27) https://keras.io/api/models/sequential/
#
# 28) https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html
